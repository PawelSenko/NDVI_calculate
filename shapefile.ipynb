# %%
import geopandas as gpd

shapefile = gpd.read_file("./field_1/Seńko_80 arów_tillage.dbf" )
print(shapefile)


shapefile.plot()
# Out:
#    Trzon                                           geometry
# 0   10.0  POLYGON ((15.31459 54.09381, 15.31459 54.09382...
# 1   11.0  POLYGON ((15.31454 54.09403, 15.31454 54.09403...
# 2   12.0  POLYGON ((15.31451 54.09413, 15.31452 54.09413...
# 3    9.0  POLYGON ((15.31448 54.09430, 15.31448 54.09430...
# 4    8.0  POLYGON ((15.31435 54.09478, 15.31435 54.09488...
# <Axes: >
